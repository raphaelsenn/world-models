# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file = f"controller-train-report.csv"
data = pd.read_csv(file)
data.head()
# Out:
#    Timesteps  Average Return
# 0          0      -47.297508

# %%
plt.plot(data["Timesteps"], data["Average Return"])
plt.show()
